# %%
import sys
from pathlib import Path

import pytest
import pandas as pd

# REPO_ROOT = Path(__file__).resolve().parents[1]
# if str(REPO_ROOT) not in sys.path:
#     sys.path.insert(0, str(REPO_ROOT))

from src.app.ingestion.standardise_tracks import standardise_tracks


CSV_CONTENT = """user_id,activity_id,timestamp,lat,lon,elevation_m,source_file
u1,a1,2026-01-01T10:01:00Z,46.5210,6.6310,455.0,activity_001.gpx
u1,a1,2026-01-01T10:00:00Z,46.5200,6.6300,450.0,activity_001.gpx
u1,a1,not_a_time,46.5220,6.6320,457.0,activity_001.gpx
u1,a1,2026-01-01T10:02:00Z,not_a_lat,6.6330,460.0,activity_001.gpx
u1,a1,2026-01-01T10:03:00Z,46.5230,181.0000,462.0,activity_001.gpx
u1,a1,2026-01-01T10:01:00Z,46.5210,6.6310,455.0,activity_001.gpx
u2,a2,2026-02-01T09:00:00Z,51.5000,-0.1200,35.0,activity_002.gpx
"""


@pytest.fixture
def sample_tracks_csv(tmp_path: Path) -> Path:
    csv_file = tmp_path / "tracks.csv"
    csv_file.write_text(CSV_CONTENT, encoding="utf-8")
    return csv_file

# %%
def test_standardise_tracks(sample_tracks_csv: Path) -> None:
    df = pd.read_csv(sample_tracks_csv)
    return df

# %%
csv_file = Path('test_data') / "tracks.csv"
csv_file.write_text(CSV_CONTENT, encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 csv_file = Path('test_data') / "tracks.csv"
# ----> 2 csv_file.write_text(CSV_CONTENT, encoding="utf-8")
#
# File ~/miniforge3/envs/powpal/lib/python3.13/pathlib/_local.py:555, in Path.write_text(self, data, encoding, errors, newline)
#     552 # Call io.text_encoding() here to ensure any warning is raised at an
#     553 # appropriate stack level.
#     554 encoding = io.text_encoding(encoding)
# --> 555 return PathBase.write_text(self, data, encoding, errors, newline)
#
# File ~/miniforge3/envs/powpal/lib/python3.13/pathlib/_abc.py:651, in PathBase.write_text(self, data, encoding, errors, newline)
#     648 if not isinstance(data, str):
#     649     raise TypeError('data must be str, not %s' %
#     650                     data.__class__.__name__)
# ...

# %%
# Out:
# PosixPath('test_data')
